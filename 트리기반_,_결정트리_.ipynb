# %% [markdown]
# <a href="https://colab.research.google.com/github/jh941213/MachineLearning/blob/main/%ED%8A%B8%EB%A6%AC%EA%B8%B0%EB%B0%98_%2C_%EA%B2%B0%EC%A0%95%ED%8A%B8%EB%A6%AC_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#트리기반 모델 소개
#결정 트리 - 스무고개 하듯이 예/아니오 질문을 이어가며 학습하는 모델
# 불순도 : 범주안에 서로 다른데이터
# 엔트로피 : 불순도를 수치적으로 나타낸 척도
# 랜덤포레스트 - 앙상블 학습법

import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
data, target = iris['data'], iris['target']

# %%
from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target = train_test_split(data, target)

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree

dt = DecisionTreeClassifier()
dt.fit(train_input, train_target)
dt.score(test_input, test_target)
# Out:
# 0.9736842105263158

# %%
import matplotlib.pyplot as plt

plt.figure(figsize =(10,10))

plot_tree(dt, feature_names = iris['feature_names'],filled=True)
# Out:
# [Text(0.5, 0.9, 'petal width (cm) <= 0.8\ngini = 0.665\nsamples = 112\nvalue = [35, 41, 36]'),
#  Text(0.4230769230769231, 0.7, 'gini = 0.0\nsamples = 35\nvalue = [35, 0, 0]'),
#  Text(0.5769230769230769, 0.7, 'petal width (cm) <= 1.75\ngini = 0.498\nsamples = 77\nvalue = [0, 41, 36]'),
#  Text(0.3076923076923077, 0.5, 'petal length (cm) <= 4.95\ngini = 0.165\nsamples = 44\nvalue = [0, 40, 4]'),
#  Text(0.15384615384615385, 0.3, 'petal width (cm) <= 1.65\ngini = 0.05\nsamples = 39\nvalue = [0, 38, 1]'),
#  Text(0.07692307692307693, 0.1, 'gini = 0.0\nsamples = 38\nvalue = [0, 38, 0]'),
#  Text(0.23076923076923078, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.3, 'petal width (cm) <= 1.55\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3]'),
#  Text(0.38461538461538464, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(train_input, train_target)
rf.score(test_input, test_target)
# Out:
# 1.0
